# %% [markdown]
# # Exploring Speed Dating Psych 15 Final Project
# Key variables
# - `iid`: unique id per subject
# - `attr1_1`, `sinc1_1`, `intel1_1`, `fun1_1`, `amb1_1`, `shar1_1`: 6 attributes at signup
# - `attr1_2`,...: 6 attributes the day after

# %%
import pandas as pd
import scipy.stats, scipy.spatial
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from jupyterthemes import jtplot
jtplot.style()
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv('Speed Dating Data.csv', encoding="latin1")
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#     ...    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  \
# 0   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 1   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 2   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 3   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 4   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
#
#    intel5_3  fun5_3  amb5_3
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
# 3       NaN     NaN     NaN
# 4       NaN     NaN     NaN
#
# [5 rows x 195 columns]

# %% [markdown]
# ## General Exploration

# %%
df[df['iid'] == 6.0][['iid', 'pid', 'match', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']]
# Out:
#     iid   pid  match  attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1
# 50    6  11.0      0     10.0     25.0      20.0    25.0     5.0     15.0
# 51    6  12.0      0     10.0     25.0      20.0    25.0     5.0     15.0
# 52    6  13.0      0     10.0     25.0      20.0    25.0     5.0     15.0
# 53    6  14.0      1     10.0     25.0      20.0    25.0     5.0     15.0
# 54    6  15.0      0     10.0     25.0      20.0    25.0     5.0     15.0
# 55    6  16.0      0     10.0     25.0      20.0    25.0     5.0     15.0
# 56    6  17.0      0     10.0     25.0      20.0    25.0     5.0     15.0
# 57    6  18.0      0     10.0     25.0      20.0    25.0     5.0     15.0
# 58    6  19.0      1     10.0     25.0      20.0    25.0     5.0     15.0
# 59    6  20.0      0     10.0     25.0      20.0    25.0     5.0     15.0

# %%
df[df['iid'] == 6.0][['iid', 'pid', 'match', 'attr1_2', 'sinc1_2', 'intel1_2', 'fun1_2', 'amb1_2', 'shar1_2']]
# Out:
#     iid   pid  match  attr1_2  sinc1_2  intel1_2  fun1_2  amb1_2  shar1_2
# 50    6  11.0      0    10.26    25.64     20.51   23.08    2.56    17.95
# 51    6  12.0      0    10.26    25.64     20.51   23.08    2.56    17.95
# 52    6  13.0      0    10.26    25.64     20.51   23.08    2.56    17.95
# 53    6  14.0      1    10.26    25.64     20.51   23.08    2.56    17.95
# 54    6  15.0      0    10.26    25.64     20.51   23.08    2.56    17.95
# 55    6  16.0      0    10.26    25.64     20.51   23.08    2.56    17.95
# 56    6  17.0      0    10.26    25.64     20.51   23.08    2.56    17.95
# 57    6  18.0      0    10.26    25.64     20.51   23.08    2.56    17.95
# 58    6  19.0      1    10.26    25.64     20.51   23.08    2.56    17.95
# 59    6  20.0      0    10.26    25.64     20.51   23.08    2.56    17.95

# %%
df[df['iid'] == 12.0][['iid', 'pid', 'match', 'pf_o_att', 'attr_o']]
# Out:
#      iid   pid  match  pf_o_att  attr_o
# 110   12   1.0      0     15.00     7.0
# 111   12   2.0      0     45.00     8.0
# 112   12   3.0      0     35.00     9.0
# 113   12   4.0      0     20.00     8.0
# 114   12   5.0      0     20.00     8.0
# 115   12   6.0      0     10.00     6.0
# 116   12   7.0      0     15.00     6.0
# 117   12   8.0      1      9.09     8.0
# 118   12   9.0      1     20.00    10.0
# 119   12  10.0      0     15.00     1.0

# %% [markdown]
# ## Actual Analysis Begins Here

# %%
# grab critical columns
attr_df = df[['iid', 
              'attr1_1', 'attr1_2', 
              'sinc1_1', 'sinc1_2', 
              'intel1_1', 'intel1_2', 
              'fun1_1', 'fun1_2', 
              'amb1_1', 'amb1_2',
              'shar1_1', 'shar1_2']].groupby('iid').mean()

# %%
attr_df.shape
# Out:
# (551, 12)

# %%
clean_attr = attr_df.dropna()
clean_attr.shape
clean_attr.head()
# Out:
# (477, 12)
#      attr1_1  attr1_2  sinc1_1  sinc1_2  intel1_1  intel1_2  fun1_1  fun1_2  \
# iid
# 1       15.0    19.44     20.0    16.67      20.0     13.89    15.0   22.22
# 2       45.0    18.92      5.0    18.92      25.0     21.62    20.0   27.03
# 4       20.0    24.14     20.0    13.79      20.0     20.69    20.0   27.59
# 5       20.0    15.79      5.0    13.16      25.0     18.42    25.0   15.79
# 6       10.0    10.26     25.0    25.64      20.0     20.51    25.0   23.08
#
#      amb1_1  amb1_2  shar1_1  shar1_2
# iid
# 1      15.0   11.11     15.0    16.67
# 2       0.0    5.41      5.0     8.11
# 4      10.0   10.34     10.0     3.45
# 5      10.0   15.79     15.0    21.05
# 6       5.0    2.56     15.0    17.95

# %% [markdown]
# ### Correlation Analysis

# %%
clean_attr.corr()
# Out:
#            attr1_1   attr1_2   sinc1_1   sinc1_2  intel1_1  intel1_2  \
# attr1_1   1.000000  0.771928 -0.422010 -0.378238 -0.343976 -0.406603
# attr1_2   0.771928  1.000000 -0.373334 -0.527767 -0.158630 -0.471293
# sinc1_1  -0.422010 -0.373334  1.000000  0.638192 -0.137212 -0.021925
# sinc1_2  -0.378238 -0.527767  0.638192  1.000000 -0.122533  0.011506
# intel1_1 -0.343976 -0.158630 -0.137212 -0.122533  1.000000  0.568652
# intel1_2 -0.406603 -0.471293 -0.021925  0.011506  0.568652  1.000000
# fun1_1   -0.146655 -0.052537 -0.180644 -0.060341 -0.132596 -0.057710
# fun1_2   -0.180016 -0.249044  0.017155 -0.041135 -0.017349 -0.034451
# amb1_1   -0.474435 -0.391812  0.017660  0.078924 -0.045548  0.140342
# amb1_2   -0.417157 -0.519622  0.031000  0.110154 -0.063057  0.099775
# shar1_1  -0.440440 -0.425658  0.023005  0.129000 -0.086810  0.110529
# shar1_2  -0.378208 -0.518080  0.148169  0.113668 -0.034437  0.000524
#
#             fun1_1    fun1_2    amb1_1    amb1_2   shar1_1   shar1_2
# attr1_1  -0.146655 -0.180016 -0.474435 -0.417157 -0.440440 -0.378208
# attr1_2  -0.052537 -0.249044 -0.391812 -0.519622 -0.425658 -0.518080
# sinc1_1  -0.180644  0.017155  0.017660  0.031000  0.023005  0.148169
# sinc1_2  -0.060341 -0.041135  0.078924  0.110154  0.129000  0.113668
# intel1_1 -0.132596 -0.017349 -0.045548 -0.063057 -0.086810 -0.034437
# intel1_2 -0.057710 -0.034451  0.140342  0.099775  0.110529  0.000524
# fun1_1    1.000000  0.520411 -0.100744 -0.092259 -0.246319 -0.161797
# fun1_2    0.520411  1.000000 -0.053554 -0.152822 -0.113356 -0.149097
# amb1_1   -0.100744 -0.053554  1.000000  0.620748  0.148719  0.153132
# amb1_2   -0.092259 -0.152822  0.620748  1.000000  0.280322  0.264089
# shar1_1  -0.246319 -0.113356  0.148719  0.280322  1.000000  0.568145
# shar1_2  -0.161797 -0.149097  0.153132  0.264089  0.568145  1.000000

# %%
attr_before = clean_attr[['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']]
attr_after = clean_attr[['attr1_2', 'sinc1_2', 'intel1_2', 'fun1_2', 'amb1_2', 'shar1_2']]
attr_after.head()
# Out:
#      attr1_2  sinc1_2  intel1_2  fun1_2  amb1_2  shar1_2
# iid
# 1      19.44    16.67     13.89   22.22   11.11    16.67
# 2      18.92    18.92     21.62   27.03    5.41     8.11
# 4      24.14    13.79     20.69   27.59   10.34     3.45
# 5      15.79    13.16     18.42   15.79   15.79    21.05
# 6      10.26    25.64     20.51   23.08    2.56    17.95

# %%
attr_after.columns = ['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']
attr_after.head()
# Out:
#      attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1
# iid
# 1      19.44    16.67     13.89   22.22   11.11    16.67
# 2      18.92    18.92     21.62   27.03    5.41     8.11
# 4      24.14    13.79     20.69   27.59   10.34     3.45
# 5      15.79    13.16     18.42   15.79   15.79    21.05
# 6      10.26    25.64     20.51   23.08    2.56    17.95

# %%
isolated_corr = attr_before.corrwith(attr_after)
isolated_corr
# Out:
# attr1_1     0.771928
# sinc1_1     0.638192
# intel1_1    0.568652
# fun1_1      0.520411
# amb1_1      0.620748
# shar1_1     0.568145
# dtype: float64

# %%
isolated_corr.to_csv('correlations.csv')

# %% [markdown]
# ### Vector Analysis

# %%
vector_attr = pd.DataFrame(
    { 
        't1': clean_attr[['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']].values.tolist(), 
        't2': clean_attr[['attr1_2', 'sinc1_2', 'intel1_2', 'fun1_2', 'amb1_2', 'shar1_2']].values.tolist()
    
    })
vector_attr.head()
# Out:
#                                      t1  \
# 0  [15.0, 20.0, 20.0, 15.0, 15.0, 15.0]
# 1     [45.0, 5.0, 25.0, 20.0, 0.0, 5.0]
# 2  [20.0, 20.0, 20.0, 20.0, 10.0, 10.0]
# 3   [20.0, 5.0, 25.0, 25.0, 10.0, 15.0]
# 4   [10.0, 25.0, 20.0, 25.0, 5.0, 15.0]
#
#                                                   t2
# 0  [19.44, 16.670000000000005, 13.89, 22.22, 11.1...
# 1  [18.920000000000005, 18.920000000000005, 21.62...
# 2  [24.139999999999997, 13.789999999999996, 20.69...
# 3  [15.789999999999996, 13.16, 18.420000000000005...
# 4  [10.260000000000002, 25.639999999999993, 20.50...

# %%
def cosine_dist(row):
    return scipy.spatial.distance.cosine(row['t1'], row['t2'])

# %%
vector_attr['cosine_dist'] = vector_attr.apply(cosine_dist, axis=1)
vector_attr.head()
# Out:
#                                      t1  \
# 0  [15.0, 20.0, 20.0, 15.0, 15.0, 15.0]
# 1     [45.0, 5.0, 25.0, 20.0, 0.0, 5.0]
# 2  [20.0, 20.0, 20.0, 20.0, 10.0, 10.0]
# 3   [20.0, 5.0, 25.0, 25.0, 10.0, 15.0]
# 4   [10.0, 25.0, 20.0, 25.0, 5.0, 15.0]
#
#                                                   t2  cosine_dist
# 0  [19.44, 16.670000000000005, 13.89, 22.22, 11.1...     0.040048
# 1  [18.920000000000005, 18.920000000000005, 21.62...     0.171478
# 2  [24.139999999999997, 13.789999999999996, 20.69...     0.037878
# 3  [15.789999999999996, 13.16, 18.420000000000005...     0.073320
# 4  [10.260000000000002, 25.639999999999993, 20.50...     0.004656

# %%
vector_attr.head().values
# Out:
# array([[[15.0, 20.0, 20.0, 15.0, 15.0, 15.0],
#         [19.44, 16.670000000000005, 13.89, 22.22, 11.11, 16.670000000000005],
#         0.040048040970961374],
#        [[45.0, 5.0, 25.0, 20.0, 0.0, 5.0],
#         [18.920000000000005, 18.920000000000005, 21.62, 27.03, 5.409999999999999, 8.11],
#         0.17147764209216176],
#        [[20.0, 20.0, 20.0, 20.0, 10.0, 10.0],
#         [24.139999999999997, 13.789999999999996, 20.69, 27.589999999999996, 10.340000000000002, 3.45],
#         0.037878141848793234],
#        [[20.0, 5.0, 25.0, 25.0, 10.0, 15.0],
#         [15.789999999999996, 13.16, 18.420000000000005, 15.789999999999996, 15.789999999999996, 21.050000000000004],
#         0.07332003948087162],
#        [[10.0, 25.0, 20.0, 25.0, 5.0, 15.0],
#         [10.260000000000002, 25.639999999999993, 20.509999999999998, 23.079999999999995, 2.5599999999999996, 17.949999999999996],
#         0.00465614167138062]], dtype=object)

# %%
cosine_dists = vector_attr['cosine_dist']
cosine_dists.shape
cosine_dists.head()
cosine_dists.hist()
# Out:
# (477,)
# 0    0.040048
# 1    0.171478
# 2    0.037878
# 3    0.073320
# 4    0.004656
# Name: cosine_dist, dtype: float64
# /anaconda/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
cosine_dists.to_csv('cosine_dists.csv')

# %%
results = scipy.stats.ttest_1samp(cosine_dists, 0)

# %%
results.statistic
# Out:
# 18.054069073991094

# %%
results.pvalue
# Out:
# 6.9273213264215534e-56

# %%
results.pvalue / 2
# Out:
# 3.4636606632107767e-56
